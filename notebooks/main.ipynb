# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score

from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn import set_config

from ipynb.fs.full.function import *

from ipynb.fs.full.pipeline import *
# Out:
# init was called!

# %%
dataset_path = "D:\Works\PAMA\exercise\datasets\FIFA23_official_data\FIFA21_official_data.csv"

df = pd.read_csv(dataset_path)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17108 entries, 0 to 17107
# Data columns (total 65 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        17108 non-null  int64
#  1   Name                      17108 non-null  object
#  2   Age                       17108 non-null  int64
#  3   Photo                     17108 non-null  object
#  4   Nationality               17108 non-null  object
#  5   Flag                      17108 non-null  object
#  6   Overall                   17108 non-null  int64
#  7   Potential                 17108 non-null  int64
#  8   Club                      16783 non-null  object
#  9   Club Logo                 17108 non-null  object
#  10  Value                     17108 non-null  object
#  11  Wage                      17108 non-null  object
#  12  Special                   17108 non-null  int64
# ...

# %%
used_columns = ["Age","Potential", "Finishing", "Dribbling", "ShortPassing", "LongPassing", "Acceleration",
                   "SprintSpeed", "Jumping", "Strength", "Wage", "Stamina", "Positioning", "Aggression"]

df_copy = df.copy()
df_copy = df_copy.dropna(subset=['Overall'])

df_copy["OK Player"] = df_copy["Overall"].apply(lambda x: 1 if x >= 75 else 0)

random_state = 42

X_train, X_test, y_train, y_test = train_test_split(df_copy[used_columns],
                                                    df_copy["OK Player"],
                                                    test_size=0.2,
                                                    random_state=random_state)

# %%
clf_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('preprocess', Preprocessor()),
#   ('column transformation',
#    ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                      transformers=[('pipeline 1',
#                                     Pipeline(steps=[('impute', SimpleImputer()),
#                                                     ('scale', StandardScaler())]),
#                                     ['Age', 'Potential', 'Finishing', 'Dribbling',
#                                      'ShortPassing', 'LongPassing', 'Acceleration',
#                                      'SprintSpeed', 'Jumping', 'Strength', 'Wage',
#                                      'Stamina', 'Positioning', 'Aggression'])])),
#   ('model', DecisionTreeClassifier())],
#  'verbose': False,
#  'preprocess': Preprocessor(),
#  'column transformation': ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                    transformers=[('pipeline 1',
# ...

# %%
clf_pipeline.fit(X_train, y_train)
# Out:
# fit was called!
# transform was called!
# Index(['Age', 'Potential', 'Finishing', 'Dribbling', 'ShortPassing',
#        'LongPassing', 'Acceleration', 'SprintSpeed', 'Jumping', 'Strength',
#        'Wage', 'Stamina', 'Positioning', 'Aggression'],
#       dtype='object')
# Pipeline(steps=[('preprocess', Preprocessor()),
#                 ('column transformation',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('pipeline 1',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Potential',
#                                                    'Finishing', 'Dribbling',
# ...

# %%
y_pred = clf_pipeline.predict(X_test)

ml_accuracy = accuracy_score(y_test, y_pred)
ml_f1_score = f1_score(y_test, y_pred)

print("\nModel Evaluation Summary:")
print(f"Accuracy: {round(ml_accuracy*100, 2)}%")
print(f"F1 score: {round(ml_f1_score*100, 2)}%")
# Out:
# transform was called!
# Index(['Age', 'Potential', 'Finishing', 'Dribbling', 'ShortPassing',
#        'LongPassing', 'Acceleration', 'SprintSpeed', 'Jumping', 'Strength',
#        'Wage', 'Stamina', 'Positioning', 'Aggression'],
#       dtype='object')
#
# Model Evaluation Summary:
# Accuracy: 97.22%
# F1 score: 89.46%

# %% [markdown]
# # BIN

# %%
columns_with_newline = df.columns[df.astype(str).apply(lambda x: x.str.contains(r"€")).any()]
columns_with_newline
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 columns_with_newline = df.columns[df.astype(str).apply(lambda x: x.str.contains(r"€")).any()]
#       2 columns_with_newline
#
# NameError: name 'df' is not defined

# %%
df[df['Value']=='€31.5M']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df[df['Value']=='€31.5M']
#
# NameError: name 'df' is not defined

# %%
# df_copy = df.copy()
# preprocessed_df = preprocessing(df_copy)
# preprocessed_df.head()

df_copy = df.copy()
preprocessor = Preprocessor(df_copy)
preprocessed_df = preprocessor.preprocessing()
preprocessed_df.head()
# Out:
#        ID              Name  Age  \
# 0  176580         L. Suárez   33
# 1  192985      K. De Bruyne   29
# 2  212198   Bruno Fernandes   25
# 3  194765      A. Griezmann   29
# 4  224334          M. Acuña   28
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/20_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/192/985/20_60.png     Belgium
# 2  https://cdn.sofifa.com/players/212/198/20_60.png    Portugal
# 3  https://cdn.sofifa.com/players/194/765/20_60.png      France
# 4  https://cdn.sofifa.com/players/224/334/20_60.png   Argentina
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       87         87    Atlético Madrid
# 1  https://cdn.sofifa.com/flags/be.png       91         91    Manchester City
# 2  https://cdn.sofifa.com/flags/pt.png       87         90  Manchester United
# ...

# %%
preprocessed_df[['Value', 'Wage', 'Release Clause']]
# Out:
#             Value      Wage  Release Clause
# 0      31500000.0  115000.0      64600000.0
# 1      87000000.0  370000.0     161000000.0
# 2      63000000.0  195000.0     124400000.0
# 3      50500000.0  290000.0     103500000.0
# 4      22000000.0   41000.0      46200000.0
# ...           ...       ...             ...
# 17103     50000.0     500.0        120000.0
# 17104     50000.0     500.0         83000.0
# 17105     60000.0     500.0        149000.0
# 17106     50000.0     500.0         94000.0
# 17107     50000.0     500.0        109000.0
#
# [17108 rows x 3 columns]
